# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms
from torch.utils.data import DataLoader

# 1. Define data transformations (scaling and normalizing the images)
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5,), (0.5,))
])

# 2. Download the MNIST dataset (60,000 training images, 10,000 testing images)
train_dataset = datasets.MNIST(root='./data', train=True, download=True, transform=transform)
test_dataset = datasets.MNIST(root='./data', train=False, download=True, transform=transform)

# 3. Create DataLoaders to serve the data in batches of 64 images
train_loader = DataLoader(dataset=train_dataset, batch_size=64, shuffle=True)
test_loader = DataLoader(dataset=test_dataset, batch_size=64, shuffle=False)

print("Data loaded successfully!")
# Out:
# 100%|██████████| 9.91M/9.91M [00:00<00:00, 19.9MB/s]
# 100%|██████████| 28.9k/28.9k [00:00<00:00, 480kB/s]
# 100%|██████████| 1.65M/1.65M [00:00<00:00, 4.48MB/s]
# 100%|██████████| 4.54k/4.54k [00:00<00:00, 12.3MB/s]
# Data loaded successfully!

# %%
# 1. Define Loss Function (How wrong the model is) and Optimizer (How it corrects itself)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

# 2. The Training Loop
epochs = 3 # We will go through the entire dataset 3 times
print("Starting Training...\n")

for epoch in range(epochs):
    running_loss = 0.0

    for images, labels in train_loader:
        # Move our data batches to the GPU to match the model
        images, labels = images.cuda(), labels.cuda()

        # Forward pass: Pass images through the network to get predictions
        outputs = model(images)
        loss = criterion(outputs, labels) # Calculate the error matrix

        # Backward pass: The calculus optimization step (Backpropagation)
        optimizer.zero_grad() # Clear previous gradients
        loss.backward()       # Compute gradients of the loss w.r.t model weights
        optimizer.step()      # Update the weights based on the gradient direction

        running_loss += loss.item()

    # Print progress at the end of each epoch
    average_loss = running_loss / len(train_loader)
    print(f"Epoch {epoch+1}/{epochs} Completed | Average Loss: {average_loss:.4f}")

print("\nTraining Finished! Your model is now trained.")
# Out:
# Starting Training...
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipykernel_2217/3093176037.py in <cell line: 0>()
#      15
#      16         # Forward pass: Pass images through the network to get predictions
# ---> 17         outputs = model(images)
#      18         loss = criterion(outputs, labels) # Calculate the error matrix
#      19
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1777             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1778         else:
# -> 1779             return self._call_impl(*args, **kwargs)
#    1780
#    1781     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
# ...

# %%
# 1. Define Loss Function and Optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

# 2. The Training Loop (CPU Version)
epochs = 3
print("Starting Training on CPU...\n")

for epoch in range(epochs):
    running_loss = 0.0

    for images, labels in train_loader:
        # REMOVED .cuda() here so data stays on the CPU with the model
        outputs = model(images)
        loss = criterion(outputs, labels)

        # Backward pass (Optimization)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        running_loss += loss.item()

    average_loss = running_loss / len(train_loader)
    print(f"Epoch {epoch+1}/{epochs} Completed | Average Loss: {average_loss:.4f}")

print("\nTraining Finished! Your model is now trained.")
# Out:
# Starting Training on CPU...
#
# Epoch 1/3 Completed | Average Loss: 0.1647
# Epoch 2/3 Completed | Average Loss: 0.0477
# Epoch 3/3 Completed | Average Loss: 0.0322
#
# Training Finished! Your model is now trained.

# %%
model.eval() # Set model to evaluation mode
correct = 0
total = 0

# Turn off gradient calculations to save memory and compute power since we are only testing, not training
with torch.no_grad():
    for images, labels in test_loader:
        # Pass test images through the network
        outputs = model(images)

        # Get the index of the highest probability output (this is the predicted digit)
        _, predicted = torch.max(outputs.data, 1)

        # Accumulate total images and correct predictions
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

final_accuracy = 100 * correct / total
print(f"Accuracy on 10,000 test images: {final_accuracy:.2f}%")
# Out:
# Accuracy on 10,000 test images: 99.14%
